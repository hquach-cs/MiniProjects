# %%
import pandas as pd 
import matplotlib.pyplot as plt

GDP = pd.read_csv("GDP.csv",thousands=',')
LE = pd.read_csv("LE.csv")
Data = {'Country':GDP['Country Name'],'GDP':GDP['2017'],'LE':LE['2017']}
Data = pd.DataFrame(Data,columns=['Country','GDP','LE'])
# Data = Data[Data['GDP'] > 0.1e13]
Data = Data.dropna()
x = Data['LE'].to_numpy()
y = Data['GDP'].to_numpy()
plt.scatter(x,y)
plt.xlabel("Life Expectancy")
plt.ylabel("GDP")
# Out:
# Text(0, 0.5, 'GDP')

# %%
import sklearn 
import numpy as np

model = sklearn.linear_model.LinearRegression()
x = np.reshape(x,(-1,1))
model.fit(x,y)
plt.scatter(x,y)
plt.plot(x,model.predict(x),color='k')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-bf79fb3939a2> in <module>
#       2 import numpy as np
#       3
# ----> 4 model = sklearn.linear_model.LinearRegression()
#       5 x = np.reshape(x,(-1,1))
#       6 model.fit(x,y)
#
# AttributeError: module 'sklearn' has no attribute 'linear_model'

# %%
x_test = [[78]] # GDP when life expectancy
